# %% [markdown]
# # Polars 🐻‍❄️

# %% [markdown]
# **Installed**

# %%
# !pip install polars openpyxl xlsxwriter pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **Imports**

# %%
import polars as pl

# %% [markdown]
# **Seleccionar las 10 primeras columnas**

# %%
PATH: str = "../processing/mis_direcciones.xlsx"

# %%
df_address = pl.read_excel(PATH, engine="openpyxl")

# %%
df_address = df_address.unique().drop_nulls()

# %%
process = df_address.head(20)

# %%
process.write_excel("../processed/seed_addresses.xlsx")
