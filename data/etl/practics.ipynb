# %%
import pandas as pd

# %%
anime_df = pd.read_csv("../anime.csv")
print(anime_df.head())
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
intersted = anime_df[["name", "genre", "episodes"]]

# %%
intersted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      12294 non-null  object
#  1   genre     12232 non-null  object
#  2   episodes  12294 non-null  object
# dtypes: object(3)
# memory usage: 288.3+ KB

# %%
intersted.drop_duplicates().head(10)
# Out:
#                                                 name  \
# 0                                     Kimi no Na wa.
# 1                   Fullmetal Alchemist: Brotherhood
# 2                                           Gintama°
# 3                                        Steins;Gate
# 4                                      Gintama&#039;
# 5  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6                             Hunter x Hunter (2011)
# 7                               Ginga Eiyuu Densetsu
# 8  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9                           Gintama&#039;: Enchousen
#
#                                                genre episodes
# 0               Drama, Romance, School, Supernatural        1
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...       64
# 2  Action, Comedy, Historical, Parody, Samurai, S...       51
# 3                                   Sci-Fi, Thriller       24
# 4  Action, Comedy, Historical, Parody, Samurai, S...       51
# ...

# %%
intersted.head()
# Out:
#                                name  \
# 0                    Kimi no Na wa.
# 1  Fullmetal Alchemist: Brotherhood
# 2                          Gintama°
# 3                       Steins;Gate
# 4                     Gintama&#039;
#
#                                                genre episodes
# 0               Drama, Romance, School, Supernatural        1
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...       64
# 2  Action, Comedy, Historical, Parody, Samurai, S...       51
# 3                                   Sci-Fi, Thriller       24
# 4  Action, Comedy, Historical, Parody, Samurai, S...       51

# %%
print(intersted['name'].count(),intersted['genre'].count(),intersted['episodes'].count())
# Out:
# 12294 12232 12294
